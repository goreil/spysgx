# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("sub_bytes.csv")
df.head()
# Out:
#                        trace_file        secret     mem0     mem1     mem2  \
# 0  trace_10000369368611929355.txt  1.000037e+19  5670672  5670648  5670668
# 1  trace_10000530007239268649.txt  1.000053e+19  5670672  5670648  5670668
# 2  trace_10000664852027228354.txt  1.000066e+19  5670672  5670648  5670668
# 3  trace_10000875258175976375.txt  1.000088e+19  5670672  5670648  5670668
# 4  trace_10002101362539977763.txt  1.000210e+19  5670672  5670648  5670668
#
#       mem3     mem4     mem5     mem6     mem7  ...    mem76    mem77  \
# 0  5670668  5670648  5670666  5670666  4276267  ...  5670666  4276394
# 1  5670668  5670648  5670666  5670666  4276297  ...  5670666  4276394
# 2  5670668  5670648  5670666  5670666  4276450  ...  5670666  4276394
# 3  5670668  5670648  5670666  5670666  4276439  ...  5670666  4276394
# 4  5670668  5670648  5670666  5670666  4276291  ...  5670666  4276394
#
#      mem78    mem79    mem80    mem81    mem82    mem83    mem84    mem85
# ...

# %%
all_accesses = df[df.columns[2:]].values.flatten()

# %%
all_accesses.max(), all_accesses.min()
# Out:
# (5670680, 4276256)

# %%
all_accesses.mean() , all_accesses.std()
# Out:
# (5540961.089328101, 404988.8828280008)
